# %%
import json
import requests

# %%
api_key = "AIzaSyBa4twbD2iqtipo3GWIVyGzGau2dYLpLUw"
url = "https://www.googleapis.com/qpxExpress/v1/trips/search?key=" + api_key
headers = {'content-type': 'application/json'}

# %%
params = {
  "request": {
    "slice": [
      {
        "origin": "TXL",
        "destination": "LIM",
        "date": "2017-12-01"
      }
    ],
    "passengers": {
      "adultCount": 1
    },
    "solutions": 50,
    "refundable": False
  }
}

# %%
response = requests.post(url, data=json.dumps(params), headers=headers)
data = response.json()
print data
# Out:
# {u'kind': u'qpxExpress#tripsSearch', u'trips': {u'tripOption': [{u'saleTotal': u'EUR727.58', u'kind': u'qpxexpress#tripOption', u'slice': [{u'duration': 1220, u'kind': u'qpxexpress#sliceInfo', u'segment': [{u'kind': u'qpxexpress#segmentInfo', u'bookingCodeCount': 9, u'flight': {u'carrier': u'AB', u'number': u'7722'}, u'leg': [{u'origin': u'TXL', u'departureTime': u'2017-12-01T16:30+01:00', u'mileage': 1028, u'destination': u'PMI', u'kind': u'qpxexpress#legInfo', u'meal': u'Food and Beverages for Purchase', u'aircraft': u'738', u'arrivalTime': u'2017-12-01T19:05+01:00', u'duration': 155, u'operatingDisclosure': u'OPERATED BY NIKI', u'id': u'L1EIYn1LDRpMyQ9Q'}], u'connectionDuration': 140, u'bookingCode': u'Q', u'duration': 155, u'id': u'G27wlGgCZ8A-h+9c', u'cabin': u'COACH', u'marriedSegmentGroup': u'0'}, {u'kind': u'qpxexpress#segmentInfo', u'bookingCodeCount': 9, u'flight': {u'carrier': u'IB', u'number': u'3921'}, u'leg': [{u'origin': u'PMI', u'originTerminal': u'D', u'departureTime': u'2017-12-01T21:25+01:00', u'destinationTerminal': u'4', u'destination': u'MAD', u'kind': u'qpxexpress#legInfo', u'meal': u'Food and Beverages for Purchase', u'aircraft': u'321', u'mileage': 339, u'arrivalTime': u'2017-12-01T22:50+01:00', u'duration': 85, u'operatingDisclosure': u'OPERATED BY IBERIA EXPRESS', u'id': u'LQ4NY7XMn1eGzzJv'}], u'connectionDuration': 105, u'bookingCode': u'S', u'duration': 85, u'id': u'GyhuHJ-k4KvaKuNc', u'cabin': u'COACH', u'marriedSegmentGroup': u'1'}, {u'kind': u'qpxexpress#segmentInfo', u'bookingCodeCount': 9, u'flight': {u'carrier': u'LA', u'number': u'2485'}, u'leg': [{u'origin': u'MAD', u'originTerminal': u'4S', u'departureTime': u'2017-12-02T00:35+01:00', u'mileage': 5917, u'destination': u'LIM', u'kind': u'qpxexpress#legInfo', u'meal': u'Breakfast', u'aircraft': u'763', u'arrivalTime': u'2017-12-02T06:50-05:00', u'duration': 735, u'operatingDisclosure': u'OPERATED BY LATAM AIRLINES PERU', u'id': u'LKfuc2zqyRUdsstO'}], u'bookingCode': u'S', u'duration': 735, u'id': u'GKX2XZvciOwdWhQ8', u'cabin': u'COACH', u'marriedSegmentGroup': u'2'}]}], u'id': u'20HBMJxy6e2VaffmG00OjV00A', u'pricing': [{u'fare': [{u'origin': u'BER', u'basisCode': u'QNCOW', u'kind': u'qpxexpress#fareInfo', u'destination': u'PMI', u'carrier': u'AB', u'id': u'Az7h6jbTwRfYO+sTo5IIUBxZhigUnMlNSzi5z2s6rtVE'}, {u'origin': u'PMI', u'basisCode': u'SLESPW0R', u'kind': u'qpxexpress#fareInfo', u'destination': u'LIM', u'carrier': u'LA', u'id': u'AUz31yvk84EzYYLI1YUocPs4njE9Dy+jabNtD/vETOKs85wHGk49WuN9bQyd+ZNR6OIe82+/NGTXLn1Co//bKRqb4Oys4n/'}], u'saleTotal': u'EUR727.58', u'kind': u'qpxexpress#pricingInfo', u'segmentPricing': [{u'kind': u'qpxexpress#segmentPricing', u'fareId': u'AUz31yvk84EzYYLI1YUocPs4njE9Dy+jabNtD/vETOKs85wHGk49WuN9bQyd+ZNR6OIe82+/NGTXLn1Co//bKRqb4Oys4n/', u'segmentId': u'GyhuHJ-k4KvaKuNc'}, {u'kind': u'qpxexpress#segmentPricing', u'fareId': u'AUz31yvk84EzYYLI1YUocPs4njE9Dy+jabNtD/vETOKs85wHGk49WuN9bQyd+ZNR6OIe82+/NGTXLn1Co//bKRqb4Oys4n/', u'segmentId': u'GKX2XZvciOwdWhQ8'}, {u'kind': u'qpxexpress#segmentPricing', u'fareId': u'Az7h6jbTwRfYO+sTo5IIUBxZhigUnMlNSzi5z2s6rtVE', u'segmentId': u'G27wlGgCZ8A-h+9c'}], u'passengers': {u'kind': u'qpxexpress#passengerCounts', u'adultCount': 1}, u'ptc': u'ADT', u'tax': [{u'kind': u'qpxexpress#taxInfo', u'code': u'QV', u'country': u'ES', u'salePrice': u'EUR3.72', u'chargeType': u'GOVERNMENT', u'id': u'QV_001'}, {u'kind': u'qpxexpress#taxInfo', u'code': u'OG', u'country': u'ES', u'salePrice': u'EUR1.11', u'chargeType': u'GOVERNMENT', u'id': u'OG_001'}, {u'kind': u'qpxexpress#taxInfo', u'code': u'JD', u'country': u'ES', u'salePrice': u'EUR16.66', u'chargeType': u'GOVERNMENT', u'id': u'JD_001'}, {u'kind': u'qpxexpress#taxInfo', u'code': u'DY', u'country': u'PE', u'salePrice': u'EUR12.62', u'chargeType': u'GOVERNMENT', u'id': u'DY_001'}, {u'kind': u'qpxexpress#taxInfo', u'code': u'DE', u'country': u'DE', u'salePrice': u'EUR7.64', u'chargeType': u'GOVERNMENT', u'id': u'DE_001'}, {u'kind': u'qpxexpress#tax ...
